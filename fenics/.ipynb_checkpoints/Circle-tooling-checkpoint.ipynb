# %%
"""
CF-PDE system on a ciruclar domain
Model is:

ct = bete*w/(b + w)*c*(1-c-f) - dc*c + Dc Lap(c)
ft = beta(1 - w/(b + w))*f*(1-c-f) - df*f + Df Lap(f)
wt = lambda - mu*w - eta*c*w + Dw Lap(w)

Want to have Dirichlet BC for oxygen and no-flow
for c and f

"""

from __future__ import print_function
from fenics import *
from mshr import *
from dolfin import *
import numpy as np
import sys

T = 20.0            # final time
num_steps = 1000    # number of time steps
dt = T / num_steps # time step size
k = Constant(dt)

# CF params
beta = 5.0
b = 1.
n = 1.0
dc = 0.1
df = 0.1
q = 0.5
eta = .5
Dc = 4e-6
Df = 4e-4
Dw = 0.5e-1
w_r = 1.0

beta = Constant(beta)
b = Constant(b)
n = Constant(n)
dc = Constant(dc)
df = Constant(df)
q = Constant(q)
eta = Constant(eta)
Dc = Constant(Dc)
Df = Constant(Df)
Dw = Constant(Dw)
w_r = Constant(w_r)

# Read mesh from file
# mesh = Mesh('navier_stokes_cylinder/cylinder.xml.gz')
L = 3.8
# L = float(sys.argv[1])
nx = ny = 30
# mesh = RectangleMesh(Point(-L, -L), Point(L, L), nx, ny)
domain = Circle(Point(0, 0), L)
mesh = generate_mesh(domain, nx)

# Define function space for system of concentrations
P1 = FiniteElement('P', triangle, 1)
element = MixedElement([P1, P1, P1])
V = FunctionSpace(mesh, element)

# Define boundary condition for oxygen
def boundary(x, on_boundary):
    return on_boundary

# v.sub(2) puts a dirichlet BC only on the
# third component (oxygen)
bc = DirichletBC(V.sub(2), w_r, boundary)

# Define test functions
v_1, v_2, v_3 = TestFunctions(V)

# Define functions for velocity and concentrations
u = Function(V)
u_n = Function(V)

# Guasian ICs for C and F
u_0 = Expression(('0.4*exp(-1*pow(x[0], 2) - 1*pow(x[1], 2))','0.2*exp(-1*pow(x[0], 2) - 1*pow(x[1], 2))','1.0'), degree = 2, L=L)
u_n = interpolate(u_0, V)

# # Constant initial conditions for checking against ODE
# u_0 = Expression(('0.4','0.3','0.1'), degree = 2)
# u_n = interpolate(u_0, V)

# Split system functions to access components
u_1, u_2, u_3 = split(u)
u_n1, u_n2, u_n3 = split(u_n)


# Define variational problem
F = ((u_1 - u_n1) / k)*v_1*dx  \
  + Dc*dot(grad(u_1), grad(v_1))*dx - (beta/( b + u_3 ))*u_3*u_1*(1-u_1-u_2)*v_1*dx + dc*u_1*v_1*dx  \
  + ((u_2 - u_n2) / k)*v_2*dx  \
  + Df*dot(grad(u_2), grad(v_2))*dx - beta*(1 - u_3/( b + u_3 ))*u_2*(1-u_1-u_2)*v_2*dx + df*u_2*v_2*dx + q*u_2*u_3*v_2*dx  \
  + ((u_3 - u_n3) / k)*v_3*dx  \
  + Dw*dot(grad(u_3), grad(v_3))*dx + eta*u_1*u_3*v_3*dx

# # Define variational problem
# F = ((u_1 - u_n1) / k)*v_1*dx  \
#   + Dc*dot(grad(u_1), grad(v_1))*dx - (pow(beta,n)/( pow(b,n) + pow(u_3,n) ))*pow(u_3,n)*u_1*(1-u_1-u_2)*v_1*dx + dc*u_1*v_1*dx  \
#   + ((u_2 - u_n2) / k)*v_2*dx  \
#   + Df*dot(grad(u_2), grad(v_2))*dx + df*u_2*v_2*dx + q*u_2*u_3*v_2*dx  - pow(beta,n)*(1 - pow(u_3,n)/( pow(b,n) + pow(u_3,n) ))*u_2*(1-u_1-u_2)*v_2*dx  \
#   + ((u_3 - u_n3) / k)*v_3*dx  \
#   + Dw*dot(grad(u_3), grad(v_3))*dx - _lambda*v_3*dx + mu*u_3*v_3*dx + eta*u_1*u_3*v_3*dx



# Create VTK files for visualization output
vtkfile_u_1 = File('cf_sys/u_1.pvd')
vtkfile_u_2 = File('cf_sys/u_2.pvd')
vtkfile_u_3 = File('cf_sys/u_3.pvd')

# Create progress bar
# progress = Progress('Time-stepping')
# set_log_level(PROGRESS)
progress = Progress('Time-stepping', num_steps)

# Time-stepping
t = 0
for n in range(num_steps):

    # Update current time
    t += dt

    # Read velocity from file
    # timeseries_w.retrieve(w.vector(), t)

    # Solve variational problem for time step
    solve(F == 0, u, bc)

    # Save solution to file (VTK)
    _u_1, _u_2, _u_3 = u.split()
    vtkfile_u_1 << (_u_1, t)
    vtkfile_u_2 << (_u_2, t)
    vtkfile_u_3 << (_u_3, t)

    # Update previous solution
    u_n.assign(u)

    # Update progress bar
    set_log_level(LogLevel.PROGRESS)
    progress += 1

# Hold plot
#interactive()

### write out function values for anaerobic population
u_1, u_2, u_3 = split(u)

# outfile = open('cf_sys/u out.txt','w')
      
# outfile.close()
# Out:
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.772e+02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 1: r (abs) = 4.033e-01 (tol = 1.000e-10) r (rel) = 2.276e-03 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 2: r (abs) = 1.270e-04 (tol = 1.000e-10) r (rel) = 7.167e-07 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 3: r (abs) = 3.498e-11 (tol = 1.000e-10) r (rel) = 1.974e-13 (tol = 1.000e-09)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.439e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 1: r (abs) = 1.013e-04 (tol = 1.000e-10) r (rel) = 4.151e-04 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 2: r (abs) = 2.179e-11 (tol = 1.000e-10) r (rel) = 8.933e-11 (tol = 1.000e-09)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.479e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 1: r (abs) = 1.029e-04 (tol = 1.000e-10) r (rel) = 4.149e-04 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 2: r (abs) = 2.209e-11 (tol = 1.000e-10) r (rel) = 8.909e-11 (tol = 1.000e-09)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.519e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 1: r (abs) = 1.044e-04 (tol = 1.000e-10) r (rel) = 4.146e-04 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 2: r (abs) = 2.237e-11 (tol = 1.000e-10) r (rel) = 8.881e-11 (tol = 1.000e-09)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.559e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 1: r (abs) = 1.060e-04 (tol = 1.000e-10) r (rel) = 4.142e-04 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 2: r (abs) = 2.264e-11 (tol = 1.000e-10) r (rel) = 8.849e-11 (tol = 1.000e-09)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.598e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 1: r (abs) = 1.075e-04 (tol = 1.000e-10) r (rel) = 4.138e-04 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 2: r (abs) = 2.290e-11 (tol = 1.000e-10) r (rel) = 8.815e-11 (tol = 1.000e-09)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# Time-stepping [>                                                      ] 0.6%
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.637e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 1: r (abs) = 1.090e-04 (tol = 1.000e-10) r (rel) = 4.132e-04 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 2: r (abs) = 2.315e-11 (tol = 1.000e-10) r (rel) = 8.780e-11 (tol = 1.000e-09)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.676e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 1: r (abs) = 1.104e-04 (tol = 1.000e-10) r (rel) = 4.126e-04 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 2: r (abs) = 2.339e-11 (tol = 1.000e-10) r (rel) = 8.743e-11 (tol = 1.000e-09)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.714e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 1: r (abs) = 1.118e-04 (tol = 1.000e-10) r (rel) = 4.119e-04 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 2: r (abs) = 2.363e-11 (tol = 1.000e-10) r (rel) = 8.706e-11 (tol = 1.000e-09)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.752e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 1: r (abs) = 1.132e-04 (tol = 1.000e-10) r (rel) = 4.112e-04 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 2: r (abs) = 2.386e-11 (tol = 1.000e-10) r (rel) = 8.669e-11 (tol = 1.000e-09)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# Time-stepping [>                                                      ] 1.0%
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.790e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 1: r (abs) = 1.145e-04 (tol = 1.000e-10) r (rel) = 4.105e-04 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 2: r (abs) = 2.408e-11 (tol = 1.000e-10) r (rel) = 8.632e-11 (tol = 1.000e-09)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.827e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 1: r (abs) = 1.158e-04 (tol = 1.000e-10) r (rel) = 4.097e-04 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 2: r (abs) = 2.430e-11 (tol = 1.000e-10) r (rel) = 8.597e-11 (tol = 1.000e-09)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.864e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 1: r (abs) = 1.171e-04 (tol = 1.000e-10) r (rel) = 4.089e-04 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 2: r (abs) = 2.452e-11 (tol = 1.000e-10) r (rel) = 8.562e-11 (tol = 1.000e-09)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2
(tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 26: r (abs) = 1.141e+35 (tol = 1.000e-10) r (rel) = 2.905e+34 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 27: r (abs) = 5.101e+35 (tol = 1.000e-10) r (rel) = 1.299e+35 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 28: r (abs) = 6.033e+38 (tol = 1.000e-10) r (rel) = 1.536e+38 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 29: r (abs) = 1.501e+38 (tol = 1.000e-10) r (rel) = 3.823e+37 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 30: r (abs) = 3.547e+37 (tol = 1.000e-10) r (rel) = 9.032e+36 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 31: r (abs) = 8.646e+36 (tol = 1.000e-10) r (rel) = 2.202e+36 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 32: r (abs) = 4.249e+36 (tol = 1.000e-10) r (rel) = 1.082e+36 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 33: r (abs) = 3.442e+37 (tol = 1.000e-10) r (rel) = 8.764e+36 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 34: r (abs) = 1.930e+39 (tol = 1.000e-10) r (rel) = 4.914e+38 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 35: r (abs) = 1.078e+39 (tol = 1.000e-10) r (rel) = 2.745e+38 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 36: r (abs) = 3.833e+41 (tol = 1.000e-10) r (rel) = 9.761e+40 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 37: r (abs) = 1.429e+41 (tol = 1.000e-10) r (rel) = 3.639e+40 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 38: r (abs) = 2.118e+42 (tol = 1.000e-10) r (rel) = 5.393e+41 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 39: r (abs) = 5.285e+41 (tol = 1.000e-10) r (rel) = 1.346e+41 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 40: r (abs) = 3.680e+43 (tol = 1.000e-10) r (rel) = 9.371e+42 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 41: r (abs) = 1.494e+43 (tol = 1.000e-10) r (rel) = 3.804e+42 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 42: r (abs) = 3.182e+42 (tol = 1.000e-10) r (rel) = 8.103e+41 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 43: r (abs) = 9.499e+41 (tol = 1.000e-10) r (rel) = 2.419e+41 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 44: r (abs) = 8.448e+41 (tol = 1.000e-10) r (rel) = 2.151e+41 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 45: r (abs) = 4.102e+42 (tol = 1.000e-10) r (rel) = 1.045e+42 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 46: r (abs) = 3.516e+42 (tol = 1.000e-10) r (rel) = 8.953e+41 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 47: r (abs) = 7.181e+43 (tol = 1.000e-10) r (rel) = 1.829e+43 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 48: r (abs) = 8.938e+43 (tol = 1.000e-10) r (rel) = 2.276e+43 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 49: r (abs) = 1.555e+43 (tol = 1.000e-10) r (rel) = 3.961e+42 (tol = 1.000e-09)
#   Solving linear system of size 5586 x 5586 (PETSc LU solver, umfpack).
#   PETSc Krylov solver starting to solve 5586 x 5586 system.
#   Newton iteration 50: r (abs) = 1.008e+44 (tol = 1.000e-10) r (rel) = 2.567e+43 (tol = 1.000e-09)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/s3/m_67b11x5lv0jmq524p2swxh0000gn/T/ipykernel_564/1791090893.py in <module>
#     130
#     131     # Solve variational problem for time step
# --> 132     solve(F == 0, u, bc)
#     133
#     134     # Save solution to file (VTK)
#
# ~/opt/anaconda3/envs/fenics2018/lib/python3.7/site-packages/dolfin/fem/solving.py in solve(*args, **kwargs)
#     218     # tolerance)
#     219     elif isinstance(args[0], ufl.classes.Equation):
# --> 220         _solve_varproblem(*args, **kwargs)
#     221
#     222     # Default case, just call the wrapped C++ solve function
#
# ~/opt/anaconda3/envs/fenics2018/lib/python3.7/site-packages/dolfin/fem/solving.py in _solve_varproblem(*args, **kwargs)
#     264         solver = NonlinearVariationalSolver(problem)
#     265         solver.parameters.update(solver_parameters)
# --> 266         solver.solve()
#     267
#     268
#
# RuntimeError:
#
# *** -------------------------------------------------------------------------
# *** DOLFIN encountered an error. If you are not able to resolve this issue
# *** using the information listed below, you can ask for help at
# ***
# ***     fenics-support@googlegroups.com
# ***
# *** Remember to include the error message listed below and, if possible,
# *** include a *minimal* running example to reproduce the error.
# ***
# *** -------------------------------------------------------------------------
# *** Error:   Unable to solve nonlinear system with NewtonSolver.
# *** Reason:  Newton solver did not converge because maximum number of iterations reached.
# *** Where:   This error was encountered inside NewtonSolver.cpp.
# *** Process: 0
# ***
# *** DOLFIN version: 2018.1.0
# *** Git changeset:
# *** -------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
fig = plot(u[2])
plt.colorbar(fig)
# Out:
# Object cannot be plotted directly, projecting to piecewise linears.
# Solving linear system of size 1880 x 1880 (PETSc LU solver, umfpack).
# PETSc Krylov solver starting to solve 1880 x 1880 system.

# %%
dt
# Out:
# 0.02

# %%
c = u[0]
f = u[1]

# %%
f([0,0])
# Out:
# 0.7753876173399816

# %% [markdown]
# mesh

# %%
dir(mesh)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_repr_html_',
#  '_repr_svg_',
#  '_ufl_domain',
#  'bounding_box_tree',
#  'cell_name',
#  'cell_orientations',
#  'cells',
#  'color',
#  'coordinates',
#  'data',
#  'domains',
#  'geometric_dimension',
#  'geometry',
#  'hash',
#  'hmax',
#  'hmin',
#  'id',
#  'init',
#  'init_cell_orientations',
#  'init_global',
#  'label',
#  'mpi_comm',
#  'name',
#  'num_cells',
#  'num_edges',
#  'num_entities',
#  'num_entities_global',
#  'num_faces',
#  'num_facets',
#  'num_vertices',
#  'order',
#  'ordered',
#  'parameters',
#  'rename',
#  'rmax',
#  'rmin',
#  'rotate',
#  'scale',
#  'smooth',
#  'smooth_boundary',
#  'snap_boundary',
#  'topology',
#  'translate',
#  'type',
#  'ufl_cell',
#  'ufl_coordinate_element',
#  'ufl_domain',
#  'ufl_id']

# %%
V = FunctionSpace(mesh, "CG", 2)
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.

# %%
V
dof_coordinates = V.tabulate_dof_coordinates()

# %%
dof_coordinates
# Out:
# array([[ 2.79374726,  0.18701937],
#        [ 2.79374726,  0.18701937],
#        [ 2.79374726,  0.18701937],
#        ...,
#        [-2.79374726,  0.18701937],
#        [-2.79374726,  0.18701937],
#        [-2.79374726,  0.18701937]])

# %%
uh = Function(V)
expr = u[2]

# %%
xyz = V.tabulate_dof_coordinates()

# %%
x = xyz[:,0]

# %%
f0 = f([0,0])
f0
# Out:
# 0.7753876173399816

# %%
f0 > 0
# Out:
# True

# %%
tol = 1e-3

# %%
f0 > tol
# Out:
# False

# %%
u[2]([0,0])
# Out:
#   Computed bounding box tree with 3019 nodes for 1510 entities.
# 277771287.01738304

# %%
plt.scatter(dof_coordinates[:,0],dof_coordinates[:,1])

# %%
dof_coordinates[:,0]
# Out:
# array([ 2.79374726,  2.79374726,  2.79374726, ..., -2.79374726,
#        -2.79374726, -2.79374726])

# %%
u[1](dof_coordinates[55])
# Out:
# 4.74095632985173e+21

# %%
dof_coordinates[1]
# Out:
# array([2.79374726, 0.18701937])

# %%
u[1]([0,0])
# Out:
# 2.5241940175371696e+22
